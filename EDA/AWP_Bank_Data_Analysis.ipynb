# %% [markdown]
# Connecting to the data source

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Reading CSV files using pandas as data frames

# %%
df = pd.read_csv("/content/drive/MyDrive/AWP Project/churn_prediction.csv")

# %% [markdown]
# # **df - Analysis**

# %%
df.head()
# Out:
#    customer_id  vintage  age gender  dependents     occupation    city  \
# 0            1     3135   66   Male         0.0  self_employed   187.0
# 1            2      310   35   Male         0.0  self_employed     NaN
# 2            4     2356   31   Male         0.0       salaried   146.0
# 3            5      478   90    NaN         NaN  self_employed  1020.0
# 4            6     2531   42   Male         2.0  self_employed  1494.0
#
#    customer_nw_category  branch_code  days_since_last_transaction  ...  \
# 0                     2          755                        224.0  ...
# 1                     2         3214                         60.0  ...
# 2                     2           41                          NaN  ...
# 3                     2          582                        147.0  ...
# 4                     3          388                         58.0  ...
#
#    previous_month_end_balance  average_monthly_balance_prevQ  \
# ...

# %% [markdown]
# **Categorical Data-**
# gender
#
# occupation
#
# city
#
# cutomer_nw_category
#
# branch
#
# churn

# %%
df.shape
# Out:
# (28382, 21)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# customer_id                         int64
# vintage                             int64
# age                                 int64
# gender                             object
# dependents                        float64
# occupation                         object
# city                              float64
# customer_nw_category                int64
# branch_code                         int64
# days_since_last_transaction       float64
# current_balance                   float64
# previous_month_end_balance        float64
# average_monthly_balance_prevQ     float64
# average_monthly_balance_prevQ2    float64
# current_month_credit              float64
# previous_month_credit             float64
# current_month_debit               float64
# previous_month_debit              float64
# current_month_balance             float64
# previous_month_balance            float64
# churn                               int64
# dtype: object

# %%
df.isna().sum()
# Out:
# customer_id                          0
# vintage                              0
# age                                  0
# gender                             525
# dependents                        2463
# occupation                          80
# city                               803
# customer_nw_category                 0
# branch_code                          0
# days_since_last_transaction       3223
# current_balance                      0
# previous_month_end_balance           0
# average_monthly_balance_prevQ        0
# average_monthly_balance_prevQ2       0
# current_month_credit                 0
# previous_month_credit                0
# current_month_debit                  0
# previous_month_debit                 0
# current_month_balance                0
# previous_month_balance               0
# churn                                0
# dtype: int64

# %%
df.head(2)
# Out:
#    customer_id  vintage  age gender  dependents     occupation   city  \
# 0            1     3135   66   Male         0.0  self_employed  187.0
# 1            2      310   35   Male         0.0  self_employed    NaN
#
#    customer_nw_category  branch_code  days_since_last_transaction  ...  \
# 0                     2          755                        224.0  ...
# 1                     2         3214                         60.0  ...
#
#    previous_month_end_balance  average_monthly_balance_prevQ  \
# 0                     1458.71                        1458.71
# 1                     8704.66                        7799.26
#
#    average_monthly_balance_prevQ2  current_month_credit  \
# 0                         1449.07                  0.20
# 1                        12419.41                  0.56
#
#    previous_month_credit  current_month_debit  previous_month_debit  \
# 0                   0.20                 0.20                  0.20
# ...

# %%
df = df.iloc[::]
df.head(2)
# Out:
#    customer_id  vintage  age gender  dependents     occupation   city  \
# 0            1     3135   66   Male         0.0  self_employed  187.0
# 1            2      310   35   Male         0.0  self_employed    NaN
#
#    customer_nw_category  branch_code  days_since_last_transaction  ...  \
# 0                     2          755                        224.0  ...
# 1                     2         3214                         60.0  ...
#
#    previous_month_end_balance  average_monthly_balance_prevQ  \
# 0                     1458.71                        1458.71
# 1                     8704.66                        7799.26
#
#    average_monthly_balance_prevQ2  current_month_credit  \
# 0                         1449.07                  0.20
# 1                        12419.41                  0.56
#
#    previous_month_credit  current_month_debit  previous_month_debit  \
# 0                   0.20                 0.20                  0.20
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28382 entries, 0 to 28381
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   customer_id                     28382 non-null  int64
#  1   vintage                         28382 non-null  int64
#  2   age                             28382 non-null  int64
#  3   gender                          27857 non-null  object
#  4   dependents                      25919 non-null  float64
#  5   occupation                      28302 non-null  object
#  6   city                            27579 non-null  float64
#  7   customer_nw_category            28382 non-null  int64
#  8   branch_code                     28382 non-null  int64
#  9   days_since_last_transaction     25159 non-null  float64
#  10  current_balance                 28382 non-null  float64
#  11  previous_month_end_balance      28382 non-null  float64
# ...

# %% [markdown]
# Change Dependent type from float to int
#
# change city type from float to int
#
# days_since_last_transaction float to int

# %%
df["dependents"] = df["dependents"].astype('Int64')
df["city"] = df["city"].astype('Int64')
df["days_since_last_transaction"] = df["days_since_last_transaction"].astype('Int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28382 entries, 0 to 28381
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   customer_id                     28382 non-null  int64
#  1   vintage                         28382 non-null  int64
#  2   age                             28382 non-null  int64
#  3   gender                          27857 non-null  object
#  4   dependents                      25919 non-null  Int64
#  5   occupation                      28302 non-null  object
#  6   city                            27579 non-null  Int64
#  7   customer_nw_category            28382 non-null  int64
#  8   branch_code                     28382 non-null  int64
#  9   days_since_last_transaction     25159 non-null  Int64
#  10  current_balance                 28382 non-null  float64
#  11  previous_month_end_balance      28382 non-null  float64
# ...

# %%
#Check for Duplicates
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [customer_id, vintage, age, gender, dependents, occupation, city, customer_nw_category, branch_code, days_since_last_transaction, current_balance, previous_month_end_balance, average_monthly_balance_prevQ, average_monthly_balance_prevQ2, current_month_credit, previous_month_credit, current_month_debit, previous_month_debit, current_month_balance, previous_month_balance, churn]
# Index: []
#
# [0 rows x 21 columns]

# %%
df[~df.duplicated()]
# Out:
#        customer_id  vintage  age  gender  dependents     occupation  city  \
# 0                1     3135   66    Male           0  self_employed   187
# 1                2      310   35    Male           0  self_employed  <NA>
# 2                4     2356   31    Male           0       salaried   146
# 3                5      478   90     NaN        <NA>  self_employed  1020
# 4                6     2531   42    Male           2  self_employed  1494
# ...            ...      ...  ...     ...         ...            ...   ...
# 28377        30297     1845   10  Female           0        student  1020
# 28378        30298     4919   34  Female           0  self_employed  1046
# 28379        30299      297   47    Male           0       salaried  1096
# 28380        30300     2585   50    Male           3  self_employed  1219
# 28381        30301     2349   18    Male           0        student  1232
#
#        customer_nw_category  branch_code  days_since_last_transaction  ...  \
# ...

# %%
df=df.drop_duplicates()

# %%
df = df.drop("vintage",axis=1)

# %%
df.head(10)
# Out:
#    customer_id  age  gender  dependents     occupation  city  \
# 0            1   66    Male           0  self_employed   187
# 1            2   35    Male           0  self_employed  <NA>
# 2            4   31    Male           0       salaried   146
# 3            5   90     NaN        <NA>  self_employed  1020
# 4            6   42    Male           2  self_employed  1494
# 5            7   42  Female           0  self_employed  1096
# 6            8   72    Male           0        retired  1020
# 7            9   46    Male           0  self_employed   623
# 8           10   31    Male           0       salaried  1096
# 9           11   40    Male           3  self_employed  1020
#
#    customer_nw_category  branch_code  days_since_last_transaction  \
# 0                     2          755                          224
# 1                     2         3214                           60
# 2                     2           41                         <NA>
# ...

# %%
#Rename the columns
df = df.rename({"customer_nw_category":"cust_nw_cat"},axis=1)

# %%
df.head(10)
# Out:
#    customer_id  age  gender  dependents     occupation  city  cust_nw_cat  \
# 0            1   66    Male           0  self_employed   187            2
# 1            2   35    Male           0  self_employed  <NA>            2
# 2            4   31    Male           0       salaried   146            2
# 3            5   90     NaN        <NA>  self_employed  1020            2
# 4            6   42    Male           2  self_employed  1494            3
# 5            7   42  Female           0  self_employed  1096            2
# 6            8   72    Male           0        retired  1020            1
# 7            9   46    Male           0  self_employed   623            2
# 8           10   31    Male           0       salaried  1096            2
# 9           11   40    Male           3  self_employed  1020            2
#
#    branch_code  days_since_last_transaction  current_balance  \
# 0          755                          224          1458.71
# ...

# %%
#Detecting The Outliers
import matplotlib.pyplot as plt
df.boxplot(column=["days_since_last_transaction"])
#This shows that there are some transactions in which last/previous transaction was done very long back

# %%
#Detecting The Outliers
import matplotlib.pyplot as plt
df.boxplot(column=["dependents"])
#This shows that there are some transactions in which last/previous transaction was done very long back

# %%
#Histogram
plt.figure(figsize=(10,8),facecolor="lightpink")
df["days_since_last_transaction"].hist(edgecolor="red",facecolor="black")

# %%
#$Stats of Diffrent column
df["days_since_last_transaction"].describe()
# Out:
# count    25159.000000
# mean        69.997814
# std         86.341098
# min          0.000000
# 25%         11.000000
# 50%         30.000000
# 75%         95.000000
# max        365.000000
# Name: days_since_last_transaction, dtype: float64

# %%
#previous_month_end_balance	
#$Stats of Diffrent column
df["previous_month_end_balance"].describe().apply(lambda x: format(x, 'f'))
# Out:
# count      28382.000000
# mean        7495.770548
# std        42529.345225
# min        -3149.570000
# 25%         1906.000000
# 50%         3379.915000
# 75%         6656.535000
# max      5740438.630000
# Name: previous_month_end_balance, dtype: object

# %%
#Bar plot
plt.figure(figsize=(5,5),facecolor="lightgreen")
df["occupation"].value_counts().plot.bar()

# %%
#Bar plot
plt.figure(figsize=(5,5),facecolor="lightgreen")
df["cust_nw_cat"].value_counts().plot.bar()

# %% [markdown]
# Missing Value Imputation

# %%
import seaborn as sns

# %%
fig, ax = plt.subplots(figsize=(15, 15))
sns.heatmap(df.isnull())
plt.show()

# %%
df[df.isnull().any(axis=1)]
# Out:
#        customer_id  age  gender  dependents     occupation  city  cust_nw_cat  \
# 1                2   35    Male           0  self_employed  <NA>            2
# 2                4   31    Male           0       salaried   146            2
# 3                5   90     NaN        <NA>  self_employed  1020            2
# 15              17   51  Female           0  self_employed  1232            3
# 21              24   29  Female           0  self_employed  1020            2
# ...            ...  ...     ...         ...            ...   ...          ...
# 28365        30285   35    Male           0  self_employed   223            2
# 28366        30286   90     NaN           0  self_employed   485            2
# 28368        30288   78  Female        <NA>  self_employed   362            2
# 28376        30296   85    Male           0        retired  1589            2
# 28380        30300   50    Male           3  self_employed  1219            3
#
# ...

# %%
df.isnull().sum()
# Out:
# customer_id                          0
# age                                  0
# gender                             525
# dependents                        2463
# occupation                          80
# city                               803
# cust_nw_cat                          0
# branch_code                          0
# days_since_last_transaction       3223
# current_balance                      0
# previous_month_end_balance           0
# average_monthly_balance_prevQ        0
# average_monthly_balance_prevQ2       0
# current_month_credit                 0
# previous_month_credit                0
# current_month_debit                  0
# previous_month_debit                 0
# current_month_balance                0
# previous_month_balance               0
# churn                                0
# dtype: int64

# %% [markdown]
# **MEAN IMPUTATION**

# %%
try:
    mean = df['days_since_last_transaction'].mean()
    df['days_since_last_transaction'] =df['days_since_last_transaction'].fillna(round(mean))
except:
    pass
  
df.head(25)
# Out:
#     customer_id  age  gender  dependents     occupation  city  cust_nw_cat  \
# 0             1   66    Male           0  self_employed   187            2
# 1             2   35    Male           0  self_employed  <NA>            2
# 2             4   31    Male           0       salaried   146            2
# 3             5   90     NaN        <NA>  self_employed  1020            2
# 4             6   42    Male           2  self_employed  1494            3
# 5             7   42  Female           0  self_employed  1096            2
# 6             8   72    Male           0        retired  1020            1
# 7             9   46    Male           0  self_employed   623            2
# 8            10   31    Male           0       salaried  1096            2
# 9            11   40    Male           3  self_employed  1020            2
# 10           12   68    Male           0        retired   409            3
# ...

# %%
#Replace NA with ) in dependents colum
df['dependents'] = df['dependents'].fillna(0)

# %%
#Replace

# %%
df[df.isnull().any(axis=1)]
# Out:
#        customer_id  age  gender  dependents     occupation  city  cust_nw_cat  \
# 1                2   35    Male           0  self_employed  <NA>            2
# 3                5   90     NaN           0  self_employed  1020            2
# 33              36   90     NaN           0  self_employed   834            3
# 41              44   90     NaN           0  self_employed  <NA>            3
# 81              85   65    Male           0            NaN   619            3
# ...            ...  ...     ...         ...            ...   ...          ...
# 28311        30227   65  Female           0        retired  <NA>            2
# 28318        30234   37    Male           0  self_employed  <NA>            2
# 28322        30238   39    Male           0       salaried  <NA>            3
# 28329        30246   42  Female           1       salaried  <NA>            2
# 28366        30286   90     NaN           0  self_employed   485            2
#
# ...

# %% [markdown]
# **MODE IMPUTATION FOR CATEGORICAL DATA -**
#
# occupation  - 80 null
#
# city   - 803 null
#
# cutomer_nw_category - 0
#
# branch  - 0
#
# churn - 0
#
# gender  - 525 null

# %%
df.isnull().sum()
# Out:
# customer_id                         0
# age                                 0
# gender                            525
# dependents                          0
# occupation                         80
# city                              803
# cust_nw_cat                         0
# branch_code                         0
# days_since_last_transaction         0
# current_balance                     0
# previous_month_end_balance          0
# average_monthly_balance_prevQ       0
# average_monthly_balance_prevQ2      0
# current_month_credit                0
# previous_month_credit               0
# current_month_debit                 0
# previous_month_debit                0
# current_month_balance               0
# previous_month_balance              0
# churn                               0
# dtype: int64

# %%
#COUNTING NUMBER OF EACH CATEGORY COUNTS IN ABOVE COLUMNS
df["occupation"].value_counts()
# Out:
# self_employed    17476
# salaried          6704
# student           2058
# retired           2024
# company             40
# Name: occupation, dtype: int64

# %%
# MODE OF OCCUPATION COL-
df["occupation"].mode()
# Out:
# 0    self_employed
# dtype: object

# %%
#COUNTING NUMBER OF EACH CATEGORY COUNTS IN ABOVE COLUMNS
df["city"].value_counts()
# Out:
# 1020    3479
# 1096    2016
# 409     1334
# 146     1291
# 834     1138
#         ...
# 689        1
# 533        1
# 117        1
# 1453       1
# 723        1
# Name: city, Length: 1604, dtype: Int64

# %%
# MODE OF OCCUPATION COL-
df["city"].mode()
# Out:
# 0    1020
# dtype: Int64

# %%
#COUNTING NUMBER OF EACH CATEGORY COUNTS IN ABOVE COLUMNS
df["gender"].value_counts()
# Out:
# Male      16548
# Female    11309
# Name: gender, dtype: int64

# %%
# MODE OF OCCUPATION COL-
df["gender"].mode()
# Out:
# 0    Male
# dtype: object

# %%
#IMPUTING MODE OF ABOVE COLS
mode_o = df['occupation'].mode()
df['occupation'] = df['occupation'].fillna(mode_o[0])

#

# %%
#IMPUTING MODE OF ABOVE COLS
mode_g = df['gender'].mode()
df['gender'] = df['gender'].fillna(mode_g[0])

# %%
#IMPUTING MODE OF ABOVE COLS
mode_c = df['city'].mode()
df['city'] = df['city'].fillna(mode_c[0])

# %%
df.isnull().sum()
# Out:
# customer_id                       0
# age                               0
# gender                            0
# dependents                        0
# occupation                        0
# city                              0
# cust_nw_cat                       0
# branch_code                       0
# days_since_last_transaction       0
# current_balance                   0
# previous_month_end_balance        0
# average_monthly_balance_prevQ     0
# average_monthly_balance_prevQ2    0
# current_month_credit              0
# previous_month_credit             0
# current_month_debit               0
# previous_month_debit              0
# current_month_balance             0
# previous_month_balance            0
# churn                             0
# dtype: int64

# %% [markdown]
# SCATTERPLOT AND CORRELATION

# %%
# sns.pairplot(df,hue="average_monthly_balance_prevQ")

# %%
df.corr()
# Out:
#                                 customer_id       age  dependents      city  \
# customer_id                        1.000000 -0.000442   -0.009110  0.000669
# age                               -0.000442  1.000000    0.001261  0.014564
# dependents                        -0.009110  0.001261    1.000000  0.003287
# city                               0.000669  0.014564    0.003287  1.000000
# cust_nw_cat                        0.009618 -0.076532    0.007917  0.009323
# branch_code                       -0.000286 -0.058990   -0.001704 -0.055779
# days_since_last_transaction        0.009665 -0.015311   -0.082712 -0.002951
# current_balance                    0.006589  0.054346   -0.003838 -0.006220
# previous_month_end_balance         0.005819  0.058342   -0.002181 -0.004634
# average_monthly_balance_prevQ      0.004485  0.061708   -0.001786 -0.006799
# average_monthly_balance_prevQ2    -0.002532  0.059607   -0.001967 -0.008213
# ...

# %%
df =pd.get_dummies(df,columns=["cust_nw_cat"])

# %%
df.head()
# Out:
#    customer_id  age gender  dependents     occupation  city  branch_code  \
# 0            1   66   Male           0  self_employed   187          755
# 1            2   35   Male           0  self_employed  1020         3214
# 2            4   31   Male           0       salaried   146           41
# 3            5   90   Male           0  self_employed  1020          582
# 4            6   42   Male           2  self_employed  1494          388
#
#    days_since_last_transaction  current_balance  previous_month_end_balance  \
# 0                          224          1458.71                     1458.71
# 1                           60          5390.37                     8704.66
# 2                           70          3913.16                     5815.29
# 3                          147          2291.91                     2291.91
# 4                           58           927.72                     1401.72
#
# ...

# %%
df=df.dropna()

# %%
df.shape
# Out:
# (28382, 22)

# %%
df.groupby(['occupation','dependents','churn'])['average_monthly_balance_prevQ'].sum().apply(lambda x: format(x, 'f'))
# Out:
# occupation     dependents  churn
# company        0           0          233728.370000
#                            1           44913.260000
#                1           0           12433.570000
#                2           0            5076.550000
#                3           0            2176.100000
# retired        0           0         9827141.090000
#                            1         2293653.930000
#                1           0          401520.440000
#                            1          144236.420000
#                2           0          319767.280000
#                            1           54298.670000
#                3           0           27757.140000
#                            1            4923.460000
#                4           0           24937.810000
#                            1           10738.720000
#                5           0            2470.470000
# salaried       0           0        33103760.120000
# ...

# %%
import pandas as pd
data = [12,3,45,41,2,6,7,91,23,11]
df2 =pd.DataFrame(data)
desc = df2.describe()
desc[0][6] - desc[0][4]
# Out:
# 30.25
